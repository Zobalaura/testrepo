# %%
####HAMOYE QUIZ
####ID: 15727ae5e981f000


import numpy as np
import pandas as pd


filename = open(r"C:\Users\USER\Documents\FoodDataSet.csv")
df = pd.read_csv(filename)
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.values
# Out:
# array([[4, 'Algeria', 2501, ..., 40551.0, 41389.0, 42228.0],
#        [4, 'Algeria', 2501, ..., 0.0, 0.0, 0.0],
#        [4, 'Algeria', 2901, ..., 3372.0, 3341.0, 3322.0],
#        ...,
#        [181, 'Zimbabwe', 2899, ..., 3.0, 1.0, 1.0],
#        [181, 'Zimbabwe', 2899, ..., 0.08, 0.04, 0.04],
#        [181, 'Zimbabwe', 2899, ..., 0.03, 0.02, 0.01]], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=60943, step=1)

# %%
df.[df.length > 7]
# Out:
#   Input In [7]
#     df.[df.length > 7]
#        ^
# SyntaxError: invalid syntax

# %%
df.sample(frac=0.5)
# Out:
#        Area Code        Area  Item Code                      Item  \
# 8391          32    Cameroon       2911                    Pulses
# 35569        136  Mauritania       2619                     Dates
# 15160         72    Djibouti       2905  Cereals - Excluding Beer
# 10882         39        Chad       2941           Animal Products
# 37614        143     Morocco       2520            Cereals, Other
# ...          ...         ...        ...                       ...
# 19049        238    Ethiopia       2511        Wheat and products
# 7209          35  Cabo Verde       2561               Sesame seed
# 18561        209    Eswatini       2923                    Spices
# 30276        123     Liberia       2635      Tea (including mate)
# 4077          20    Botswana       2805         Rice and products
#
#        Element Code                                 Element          Unit  \
# 8391           5072                         Stock Variation   1000 tonnes
# ...

# %%
df.nlargest(2, 10)

# %%
df.tail()

# %%
pd.isnull(df["Area"])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60938    False
# 60939    False
# 60940    False
# 60941    False
# 60942    False
# Name: Area, Length: 60943, dtype: bool

# %%
pd.notnull("Item code")
# Out:
# True

# %%
df.sort_values('Element Code')
# Out:
#        Area Code           Area  Item Code                  Item  \
# 0              4        Algeria       2501            Population
# 25671        175  Guinea-Bissau       2501            Population
# 59550        181       Zimbabwe       2501            Population
# 19008        238       Ethiopia       2501            Population
# 51221        276          Sudan       2501            Population
# ...          ...            ...        ...                   ...
# 34625        133           Mali       2733               Pigmeat
# 4803          20       Botswana       2616             Plantains
# 24372         90         Guinea       2517   Millet and products
# 8735          32       Cameroon       2579        Sesameseed Oil
# 36239        137      Mauritius       2532  Cassava and products
#
#        Element Code                        Element          Unit    Y2014  \
# 0               511  Total Population - Both sexes  1000 persons  38924.0
# ...

# %%
df.sort_values('Area Code', ascending=False)

# %%
df.sort_index()

# %%
# df.drop(columns=['',''])

# %%
df.iat[1:9]

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
df.nunique()
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %%
df.groupby(by ='Element')

# %%
df.dropna()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
df.unique('Area')

# %%
print(df.mean())

# %%
df['Y2015'].mean()
# Out:
# 135.23596649549236

# %%
percent = 100*(len(df.loc[:, df.isnull().sum(axis=0)>=1] .index) /len(df.index))

# %%
print(percent)
# Out:
# 100.0

# %%
rt = df.groupby('Element Code').max()
print(rt.sort_values)
# Out:
# <bound method DataFrame.sort_values of               Area Code                   Area  Item Code        Item  \
# Element Code
# 511                 276               Zimbabwe       2501  Population
# 645                 276               Zimbabwe       2961        Yams
# 664                 276               Zimbabwe       2961        Yams
# 674                 276               Zimbabwe       2961        Yams
# 684                 276               Zimbabwe       2961        Yams
# 5072                276               Zimbabwe       2961        Yams
# 5123                276               Zimbabwe       2949        Yams
# 5131                276               Zimbabwe       2948        Wine
# 5142                276               Zimbabwe       2961        Yams
# 5154                276               Zimbabwe       2961        Yams
# 5170                276               Zimbabwe       2949        Yams
# 5171                193  Sao Tome and Principe       2949        Yams
# ...

# %%
print(df.sort_values("Y2018").sum())
# Out:
# Area Code                                                 8182547
# Area            EgyptEgyptEgyptEgyptMozambiqueMozambiqueEthiop...
# Item Code                                               163764610
# Item            Cereals - Excluding BeerMaize and productsSuga...
# Element Code                                            232488797
# Element         Stock VariationStock VariationStock VariationS...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                  7965086.13
# Y2015                                                  8032340.23
# Y2016                                                  8112472.65
# Y2017                                                  8375729.19
# Y2018                                                  8554629.96
# dtype: object

# %%
fg = df.groupby(['Y2018', 'Element']).sum()
print(fg.tail())
# Out:
#                                         Area Code  Item Code  Element Code  \
# Y2018    Element
# 98424.0  Total Population - Both sexes         59       2501           511
# 109224.0 Total Population - Both sexes        238       2501           511
# 117038.0 Domestic supply quantity             159       2907          5301
# 118172.0 Production                           159       2907          5511
# 195875.0 Total Population - Both sexes        159       2501           511
#
#                                            Y2014     Y2015     Y2016     Y2017
# Y2018    Element
# 98424.0  Total Population - Both sexes   90425.0   92443.0   94447.0   96443.0
# 109224.0 Total Population - Both sexes   98094.0  100835.0  103603.0  106400.0
# 117038.0 Domestic supply quantity       108756.0  110798.0  116483.0  112625.0
# 118172.0 Production                     109593.0  111663.0  119330.0  117702.0
# 195875.0 Total Population - Both sexes  176405.0  181137.0  185960.0  190873.0
